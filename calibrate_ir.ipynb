# %%
from calibration_tool import calibrate_cameras

# %%
rgb_path = "../ICIP_2025/RGB-IR/billiards_all/low/images/camera_0_20241208_225112_281002.png"
ir_path = "../ICIP_2025/RGB-IR/billiards_all/low/images/camera_1_20241208_225112_281002.png"
calibration_matrix = "./calibration/billiards_low.json"

# %%
transform_matrix = calibrate_cameras(rgb_path, ir_path, calibration_matrix)
# Out:
# Select corresponding points on RGB image:
#
# Selecting points for RGB image.
# Click to select points. Press:
#   'r' to reset all points
#   'c' to clear last point
#   'q' to finish selection
#
# Recommended: Select 8-12 well-distributed points
# QObject::moveToThread: Current thread (0x2de30780) is not the object's thread (0x2e61bac0).
# Cannot move to target thread (0x2de30780)
#
# QObject::moveToThread: Current thread (0x2de30780) is not the object's thread (0x2e61bac0).
# Cannot move to target thread (0x2de30780)
#
# QObject::moveToThread: Current thread (0x2de30780) is not the object's thread (0x2e61bac0).
# Cannot move to target thread (0x2de30780)
#
# QObject::moveToThread: Current thread (0x2de30780) is not the object's thread (0x2e61bac0).
# Cannot move to target thread (0x2de30780)
#
# QObject::moveToThread: Current thread (0x2de30780) is not the object's thread (0x2e61bac0).
# Cannot move to target thread (0x2de30780)
#
# ...
